# %%
# -*- coding: utf-8 -*-
# vispy: gallery 30
# -----------------------------------------------------------------------------
# Copyright (c) Vispy Development Team. All Rights Reserved.
# Distributed under the (new) BSD License. See LICENSE.txt for more info.
# -----------------------------------------------------------------------------
"""
Simple use of SceneCanvas to display an Image.
"""
import sys
from vispy import scene
from vispy import app
from vispy.io import load_data_file, read_png

canvas = scene.SceneCanvas(keys='interactive')
canvas.size = 800, 600
canvas.show()

# Set up a viewbox to display the image with interactive pan/zoom
view = canvas.central_widget.add_view()

# Create the image
img_data = read_png(load_data_file('mona_lisa/mona_lisa_sm.png'))
interpolation = 'nearest'

image = scene.visuals.Image(img_data, interpolation=interpolation,
                            parent=view.scene, method='subdivide')
# image.interactive = True

# canvas.title = 'Spatial Filtering using %s Filter' % interpolation

# Set 2D camera (the camera will scale to the contents in the scene)
view.camera = scene.PanZoomCamera(aspect=1)
# flip y-axis to have correct aligment
view.camera.flip = (0, 1, 0)
view.camera.set_range()
view.camera.zoom(0.1, (250, 200))

# get interpolation functions from Image
names = image.interpolation_functions
names = list(names)
names.sort()
act = 17


# Implement key presses
@canvas.events.key_press.connect
def on_key_press(event):
    global act
    if event.key in ['Left', 'Right']:
        if event.key == 'Right':
            step = 1
        else:
            step = -1
        act = (act + step) % len(names)
        interpolation = names[act]
        image.interpolation = interpolation
#         canvas.title = 'Spatial Filtering using %s Filter' % interpolation
        canvas.update()
# Out:
# /Users/davidh/anaconda/envs/vispy_py37_pyqt5/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# VispyWidget(height=600, width=800)
# mouse_press Event received in gen event:  {'type': 'mouse_press', 'pos': [768.171875, 444.03125], 'button': 1, 'is_dragging': False, 'modifiers': [], 'delta': None, 'press_event': None, 'last_event': None}
# bounds checking for  [768.171875 444.03125 ]
# _visual_bounds_at:  <SubScene at 0x1c2385cc88> <Widget at 0x110911c88> [768.171875 444.03125 ]
# _visual_bounds_at:  <Widget at 0x110911c88> <ViewBox at 0x1c23882d68> [768.171875 444.03125 ]
# _visual_bounds_at:  <ViewBox at 0x1c23882d68> <SubScene at 0x1c239cc240> [768.171875 444.03125 ]
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <BaseCamera at 0x1c238665c0> [768.171875 444.03125 ]
# Currently analyzing:  <BaseCamera at 0x1c238665c0>
# Returning none for visual bounds at:  False True True
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <Image at 0x1c238c3d30> [768.171875 444.03125 ]
# Currently analyzing:  <Image at 0x1c238c3d30>
# Returning none for visual bounds at:  True True False
# Bounds:  [(0, 558), (0, 833)]
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <PanZoomCamera at 0x1c238c3eb8> [768.171875 444.03125 ]
# Currently analyzing:  <PanZoomCamera at 0x1c238c3eb8>
# Returning none for visual bounds at:  False True True
# Currently analyzing:  <SubScene at 0x1c239cc240>
# Returning none for visual bounds at:  False True N/A
# Currently analyzing:  <ViewBox at 0x1c23882d68>
# <vispy.visuals.mesh.MeshVisual object at 0x1c23882780> False None
# <vispy.visuals.mesh.MeshVisual object at 0x1c238b4828> True (0.0, 800.0)
# <vispy.visuals.mesh.MeshVisual object at 0x1c23882780> False None
# <vispy.visuals.mesh.MeshVisual object at 0x1c238b4828> True (0.0, 600.0)
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# mouse_press Event received in gen event:  {'type': 'mouse_press', 'pos': [791.171875, 386.03125], 'button': 1, 'is_dragging': False, 'modifiers': [], 'delta': None, 'press_event': None, 'last_event': None}
# bounds checking for  [791.171875 386.03125 ]
# _visual_bounds_at:  <SubScene at 0x1c2385cc88> <Widget at 0x110911c88> [791.171875 386.03125 ]
# _visual_bounds_at:  <Widget at 0x110911c88> <ViewBox at 0x1c23882d68> [791.171875 386.03125 ]
# _visual_bounds_at:  <ViewBox at 0x1c23882d68> <SubScene at 0x1c239cc240> [791.171875 386.03125 ]
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <BaseCamera at 0x1c238665c0> [791.171875 386.03125 ]
# Currently analyzing:  <BaseCamera at 0x1c238665c0>
# Returning none for visual bounds at:  False True True
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <Image at 0x1c238c3d30> [791.171875 386.03125 ]
# Currently analyzing:  <Image at 0x1c238c3d30>
# Returning none for visual bounds at:  True True False
# Bounds:  [(0, 558), (0, 833)]
# _visual_bounds_at:  <SubScene at 0x1c239cc240> <PanZoomCamera at 0x1c238c3eb8> [791.171875 386.03125 ]
# Currently analyzing:  <PanZoomCamera at 0x1c238c3eb8>
# Returning none for visual bounds at:  False True True
# Currently analyzing:  <SubScene at 0x1c239cc240>
# Returning none for visual bounds at:  False True N/A
# Currently analyzing:  <ViewBox at 0x1c23882d68>
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
# _process_mouse_event:  MouseEvent SceneMouseEvent <ViewBox at 0x1c23882d68>
# Mouse event in python!:  False True
